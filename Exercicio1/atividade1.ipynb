# %% [markdown]
# Exercicio 1
# Crie um programa que mostre na tela

# %%
a = "Eu estou aprendendo Python"
print (a)
# Out:
# Eu estou aprendendo Python

# %%
Exercicio 2
Crie um programa que mostre:

# %%
u = "Meu nome é Gabriel"
y = "Eu moro em Goiania"
print(u,y)
# Out:
# Meu nome é Gabriel Eu moro em Goiania

# %%
nome_do_aluno = "Gabriel"
idade_do_aluno = "27 anos"
print("Meu nome é", nome_do_aluno, "tenho", idade_do_aluno, "e moro em Goiania")
# Out:
# Meu nome é Gabriel tenho 27 anos e moro em Goiania

# %%
cidade = "goiania"
estado = "goias"
pais = "brasil"
print("Meu nome é Gabriel e eu moro em", cidade, "do estado de", estado, "no", pais)
# Out:
# Meu nome é Gabriel e eu moro em goiania do estado de goias no brasil

# %%
a = input("qual é o seu nome? ")
b = input("em que cidade voce mora? ")
print("ola", a, "voce mora em", b)
# Out:
# qual é o seu nome?  gabriel
# em que cidade voce mora?  goiania
# ola gabriel voce mora em goiania
